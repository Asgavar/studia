# %% [markdown]
# # Lista 06

# %% [markdown]
# ## Implementacja APRIORI i jego komponentów

# %%
import functools
import itertools

import numpy as np
import pandas as pd
import scipy.sparse

# %% [markdown]
# ### Wczytywanie używanych później datasetów

# %%
def load_dataset(filename):
    rows = []
    with open(filename) as dataset:
        for line in dataset:
            rows.append([int(item) for item in line.split()]) # wiersz 0 i kolumna 0 być może pozostaną puste, trudno
    matrix = scipy.sparse.lil_matrix(
        (1+len(rows), 1+max([max([v for v in r]) for r in rows])), dtype='?')
    print(matrix.shape)
    for idx, r in enumerate(rows):
        matrix[idx, r] = True
    return matrix.tocsc()

# %%
DATASETS = {}

# %% [markdown]
# ### Właściwy algorytm

# %%
@functools.lru_cache(maxsize=42_000_000)
def indices_containing(matrix_name, item):
    return set(DATASETS[matrix_name][:, item].nonzero()[0].tolist())

# %%
def support(matrix_name, itemset):
    first_element = True
    indices = set()
    for item in itemset:
        this_item_indices = indices_containing(matrix_name, item)
        indices = this_item_indices if first_element else indices & this_item_indices
        first_element = False
    return len(indices)

# %%
def gen_frequent_itemsets(matrix_name, min_supp):
    matrix = DATASETS[matrix_name]
    min_supp = min_supp if min_supp == round(min_supp) else min_supp * matrix.shape[0]
    sets = {}
    sets[1] = [
        {col}
        for col in range(matrix.shape[1]) if support(matrix_name, {col}) > min_supp
    ]
    K = 2
    while sets[K-1]:
        print(f'doing K = {K}')
        print(len(sets[K-1]))
        sets[K] = set([
            frozenset(oldset | {newelem})
            for newelem in
                functools.reduce(lambda s1, s2: s1 | s2, sets[K-1])  # flatten
            for oldset in sets[K-1]
        ])
        sets[K] = list(filter(
            lambda newset: 
                support(matrix_name, newset) > min_supp
                and len(newset) == K,
            sets[K]))
        K += 1
    
    return functools.reduce(lambda s1, s2: s1 + s2, sets.values())

# %%
def gen_association_rules(matrix_name, itemsets, min_confidence):
    matrix = DATASETS[matrix_name]
    rules = []
    matrix_size = matrix.shape[0]

    for itemset in itemsets:
        itemset = list(itemset)
        antedecent_count = 1
        antedecents = set(itemset[:antedecent_count])
        consequents = set(itemset[antedecent_count:])
        while (confidence := \
            support(matrix_name, full_set := antedecents | consequents) / \
            support(matrix_name, antedecents)) >= min_confidence \
            and antedecent_count < len(full_set):
                
            antedecents = set(itemset[:antedecent_count])
            consequents = set(itemset[antedecent_count:])
            rules.append({
                'rule': f'{antedecents} -> {consequents}',
                'fractional support': support(matrix_name, antedecents | consequents) / matrix_size,
                'confidence': confidence,
                'lift': confidence / (support(matrix_name, consequents) / matrix_size),
                'leverage':
                    (support(matrix_name, antedecents | consequents) / matrix_size) - \
                        (support(matrix_name, antedecents) / matrix_size) * \
                            (support(matrix_name, consequents) / matrix_size)
            })
            antedecent_count += 1
            
    return pd.DataFrame(rules)

# %%
def apriori(matrix_name, min_support, min_confidence):
    frequent_itemsets = gen_frequent_itemsets(matrix_name, min_support)
    return gen_association_rules(matrix_name, frequent_itemsets, min_confidence)

# %% [markdown]
# ## Zestaw danych z artykułu na Wikipedii

# %%
wiki_matrix = load_dataset('wiki.dat')
# Out:
# (8, 5)

# %%
DATASETS['wiki'] = wiki_matrix

# %%
apriori('wiki', 0, 0).sort_values('lift', ascending=False)
# Out:
# doing K = 2
# 4
# doing K = 3
# 6
# doing K = 4
# 4
# doing K = 5
# 1
#                 rule  fractional support  confidence      lift  leverage
# 8      {1} -> {2, 4}               0.250    0.666667  1.333333  0.062500
# 3         {1} -> {2}               0.375    1.000000  1.333333  0.093750
# 14  {1} -> {2, 3, 4}               0.125    0.333333  1.333333  0.031250
# 0         {3} -> {4}               0.375    0.750000  1.200000  0.062500
# 4         {2} -> {4}               0.500    0.666667  1.066667  0.031250
# 1         {1} -> {4}               0.250    0.666667  1.066667  0.015625
# 9      {1, 2} -> {4}               0.250    0.666667  1.066667  0.015625
# 2         {2} -> {3}               0.375    0.500000  1.000000  0.000000
# 6      {2} -> {3, 4}               0.250    0.333333  0.888889 -0.031250
# 10     {1} -> {2, 3}               0.125    0.333333  0.888889 -0.015625
# 12     {1} -> {3, 4}               0.125    0.333333  0.888889 -0.015625
# 15  {1, 2} -> {3, 4}               0.125    0.333333  0.888889 -0.015625
# 5         {1} -> {3}               0.125    0.333333  0.666667 -0.062500
# 11     {1, 2} -> {3}               0.125    0.333333  0.666667 -0.062500
# 7      {2, 3} -> {4}               0.250    0.333333  0.533333  0.015625
# 13     {1, 3} -> {4}               0.125    0.333333  0.533333  0.046875
# 16  {1, 2, 3} -> {4}               0.125    0.333333  0.533333  0.046875

# %% [markdown]
# ## Zestaw danych RETAIL

# %%
retail_matrix = load_dataset('retail.dat')
retail_matrix[:20]
# Out:
# (88163, 16470)
# <20x16470 sparse matrix of type '<class 'numpy.bool_'>'
# 	with 152 stored elements in Compressed Sparse Column format>

# %%
DATASETS['retail'] = retail_matrix

# %%
retail_res = apriori('retail', 0.02, 0.3)
# Out:
# doing K = 2
# 355
# doing K = 3
# 388
# doing K = 4
# 169
# doing K = 5
# 29
# doing K = 6
# 4

# %%
retail_res_sorted = retail_res.sort_values('confidence', ascending=False)

# %%
# retail_res_sorted[abs(retail_res_sorted['leverage']) >= 0.01].head(40)
retail_res_sorted.head(40)
# Out:
#                    rule  fractional support  confidence        lift  leverage
# 121       {371} -> {38}            0.008700    0.980818    5.544492  0.007131
# 64        {105} -> {38}            0.007293    0.978691    5.532466  0.005975
# 84        {170} -> {38}            0.034380    0.978057    5.528884  0.028161
# 173      {3904} -> {38}            0.003777    0.976540    5.520304  0.003093
# 124        {37} -> {38}            0.011864    0.973929    5.505548  0.009709
# 13        {840} -> {38}            0.004299    0.969309    5.479433  0.003514
# 70        {370} -> {38}            0.004106    0.965333    5.456956  0.003354
# 154        {56} -> {38}            0.005830    0.960748    5.431033  0.004757
# 49        {281} -> {38}            0.004900    0.953642    5.390868  0.003991
# 118        {36} -> {38}            0.031646    0.950272    5.371818  0.025755
# 74   {16430} -> {16431}            0.003947    0.816901  205.186549  0.003928
# 37         {41} -> {39}            0.129465    0.763734    1.328723  0.032029
# 15        {979} -> {39}            0.003766    0.756264    1.315728  0.000904
# 134      {2238} -> {39}            0.014598    0.750437    1.305591  0.003417
# 174        {78} -> {39}            0.008779    0.730189    1.270363  0.001868
# 24       {2958} -> {39}            0.007429    0.724558    1.260566  0.001536
# 120       {225} -> {39}            0.026667    0.721830    1.255820  0.005432
# 48         {89} -> {39}            0.031181    0.716445    1.246452  0.006165
# 156      {8978} -> {39}            0.004911    0.714521    1.243105  0.000960
# 41        {310} -> {39}            0.021007    0.713955    1.242120  0.004095
# 94        {570} -> {39}            0.006329    0.704545    1.225749  0.001166
# 100       {156} -> {39}            0.006601    0.701205    1.219937  0.001190
# 18        {267} -> {39}            0.004616    0.696918    1.212479  0.000809
# 171       {790} -> {39}            0.004129    0.695985    1.210855  0.000719
# 144        {36} -> {39}            0.023105    0.693801    1.207056  0.003963
# 8         {105} -> {39}            0.005161    0.692542    1.204866  0.000878
# 91        {475} -> {39}            0.017014    0.692201    1.204273  0.002886
# 164        {48} -> {39}            0.330547    0.691634    1.203286  0.055843
# 35        {789} -> {39}            0.005070    0.689815    1.200121  0.000845
# 20         {53} -> {39}            0.003981    0.689587    1.199726  0.000663
# 167      {1146} -> {39}            0.011150    0.689341    1.199297  0.001853
# 17        {675} -> {39}            0.004696    0.688852    1.198446  0.000778
# 50        {270} -> {39}            0.013543    0.688581    1.197975  0.002238
# 23       {2284} -> {39}            0.003959    0.687008    1.195238  0.000647
# 39        {272} -> {39}            0.005059    0.686154    1.193752  0.000821
# 177        {49} -> {39}            0.008711    0.685714    1.192987  0.001409
# 87       {1814} -> {39}            0.005342    0.684593    1.191037  0.000857
# 185   {105} -> {38, 39}            0.005093    0.683409    5.824207  0.004218
# 186   {105, 38} -> {39}            0.005093    0.683409    1.188977  0.000901
# 28         {56} -> {39}            0.004129    0.680374    1.183696  0.000641

# %% [markdown]
# ## Zestaw danych KOSARAK

# %%
kosarak_matrix = load_dataset('kosarak.dat')
kosarak_matrix
# Out:
# (990003, 41271)
# <990003x41271 sparse matrix of type '<class 'numpy.bool_'>'
# 	with 8018988 stored elements in Compressed Sparse Column format>

# %%
DATASETS['kosarak'] = kosarak_matrix

# %%
kosarak_res = apriori('kosarak', 0.2, 0.3)
# Out:
# doing K = 2
# 70
# doing K = 3
# 187
# doing K = 4
# 186
# doing K = 5
# 80
# doing K = 6
# 16
# doing K = 7
# 1

# %%
kosarak_res.sort_values('confidence', ascending=False).head(50)
# Out:
#                     rule  fractional support  confidence       lift  leverage
# 81          {438} -> {6}            0.018566    0.971973   1.600095  0.006963
# 66          {254} -> {6}            0.009842    0.966954   1.591834  0.003659
# 24           {85} -> {6}            0.008595    0.966822   1.591616  0.003195
# 45          {364} -> {6}            0.011874    0.966138   1.590490  0.004408
# 62           {90} -> {6}            0.021503    0.964917   1.588480  0.007966
# 43           {25} -> {6}            0.012341    0.964477   1.587757  0.004569
# 29          {229} -> {6}            0.009775    0.964421   1.587664  0.003618
# 3           {155} -> {6}            0.011178    0.962763   1.584935  0.004125
# 71           {85} -> {7}            0.008558    0.962618  10.966818  0.007777
# 78          {379} -> {6}            0.009508    0.962179   1.583973  0.003505
# 41           {56} -> {6}            0.015304    0.961846   1.583425  0.005639
# 88           {49} -> {6}            0.012332    0.961187   1.582340  0.004539
# 5           {512} -> {6}            0.012538    0.960684   1.581512  0.004610
# 37          {747} -> {6}            0.009083    0.959863   1.580161  0.003335
# 91           {21} -> {6}            0.008464    0.956179   1.574096  0.003087
# 69          {361} -> {6}            0.009748    0.953468   1.569632  0.003538
# 79           {46} -> {6}            0.008474    0.950380   1.564548  0.003058
# 49          {916} -> {6}            0.008616    0.948938   1.562174  0.003101
# 107       {85, 6} -> {7}            0.008370    0.941484  10.726046  0.007615
# 106       {85} -> {6, 7}            0.008370    0.941484  12.662300  0.007709
# 90          {378} -> {6}            0.010830    0.931700   1.533797  0.003769
# 77           {83} -> {6}            0.030286    0.930802   1.532319  0.010521
# 53          {667} -> {6}            0.009979    0.930576   1.531948  0.003465
# 59          {148} -> {6}            0.065404    0.926032   1.524466  0.022501
# 17           {40} -> {6}            0.022489    0.924508   1.521957  0.007713
# 30          {987} -> {6}            0.016596    0.922826   1.519189  0.005672
# 100          {28} -> {6}            0.009408    0.921175   1.516471  0.003204
# 214  {897, 11, 6} -> {7}            0.009952    0.917412  10.451796  0.009010
# 85          {897} -> {6}            0.013200    0.914038   1.504721  0.004428
# 15           {32} -> {6}            0.010202    0.912458   1.502121  0.003410
# 60          {205} -> {6}            0.019679    0.911524   1.500583  0.006565
# 12           {28} -> {7}            0.009283    0.908911  10.354953  0.008386
# 4           {321} -> {6}            0.008752    0.906476   1.492272  0.002887
# 99           {69} -> {6}            0.020645    0.903142   1.486784  0.006759
# 16          {136} -> {6}            0.021403    0.894844   1.473123  0.006874
# 22          {314} -> {6}            0.013415    0.894825   1.473093  0.004308
# 39           {32} -> {7}            0.009994    0.893848  10.183340  0.009013
# 205   {32, 28, 6} -> {7}            0.008627    0.892570  10.168781  0.007833
# 211  {897, 27, 6} -> {7}            0.009258    0.892405  10.166905  0.008402
# 64          {897} -> {7}            0.012877    0.891656  10.158366  0.011609
# 93           {14} -> {6}            0.010454    0.891617   1.467811  0.003332
# 76           {11} -> {6}            0.327285    0.889987   1.465127  0.103902
# 1           {273} -> {6}            0.015424    0.888979   1.463469  0.004885
# 32          {737} -> {6}            0.015658    0.878492   1.446205  0.004831
# 8           {218} -> {6}            0.078459    0.876713   1.443275  0.024097
# 2            {77} -> {6}            0.038034    0.866526   1.426505  0.011372
# 48          {32} -> {28}            0.009666    0.864486  84.644855  0.009551
# 25          {90} -> {11}            0.019249    0.863793   2.348915  0.011054
# 54          {504} -> {6}            0.012682    0.863124   1.420905  0.003757
# 121      {90, 11} -> {6}            0.019171    0.860257   1.416186  0.007478

# %% [markdown]
# ## Zestaw danych Ta-Feng

# %%
tafeng_columns = [
    'timestamp', 'customer', 'age_group', 'zipcode_area',
    'prod_subclass', 'prod_id', 'prod_amount', 'asset', 'sales_price'
]
TAFENG_TRANSFORMATORS = {}

# %%
tafeng_11 = pd.read_csv('D11', sep=';', names=tafeng_columns)
tafeng_12 = pd.read_csv('D12', sep=';', names=tafeng_columns)
tafeng_01 = pd.read_csv('D01', sep=';', names=tafeng_columns)
tafeng_02 = pd.read_csv('D02', sep=';', names=tafeng_columns)

taf = [tafeng_11, tafeng_12, tafeng_01, tafeng_02]

for idx, _ in enumerate(taf):
    # przy mojej implementacji przy użyciu sparse matrixów te wartości są po prostu za duże
    max_subclass_id = max(taf[idx]['prod_subclass'].unique())
    TAFENG_TRANSFORMATORS[idx] = {
        k: 100+max_subclass_id+v for v, k in enumerate(taf[idx]['prod_id'].unique())
    }

    taf[idx] = taf[idx].replace({'prod_id': TAFENG_TRANSFORMATORS[idx]})
    taf[idx] = taf[idx].groupby(['timestamp', 'customer'], as_index=False).agg(
        lambda cell: 
            cell.tolist() if cell.name not in ('age_group', 'zipcode_area') else cell.tolist()[0])

taf[0]
# Out:
#                  timestamp  customer age_group zipcode_area  \
# 0      2000-11-01 00:00:00     38317        J            E
# 1      2000-11-01 00:00:00     45902        H            E
# 2      2000-11-01 00:00:00     45957        G            E
# 3      2000-11-01 00:00:00     46855        D            E
# 4      2000-11-01 00:00:00     58698        D            E
# ...                    ...       ...       ...          ...
# 31855  2000-11-30 00:00:00   2161983        H            G
# 31856  2000-11-30 00:00:00   2162003        C            C
# 31857  2000-11-30 00:00:00   2162027        F            C
# 31858  2000-11-30 00:00:00   2162034        D            F
# 31859  2000-11-30 00:00:00   2162065        F            D
#
#                                            prod_subclass  \
# 0                                       [130315, 120105]
# 1                       [100304, 130204, 100511, 100113]
# 2                                               [110217]
# 3                               [110411, 110401, 110117]
# 4       [130201, 130204, 110401, 130206, 120109, 120109]
# ...                                                  ...
# 31855  [110117, 130404, 130206, 110105, 110208, 76013...
# 31856                   [720221, 500205, 500202, 500201]
# 31857  [100413, 520144, 520211, 520213, 500316, 10041...
# 31858                           [100508, 100414, 100414]
# 31859                                   [110106, 560201]
#
#                                                  prod_id  \
# 0                                       [780611, 780783]
# 1                       [781334, 780814, 781339, 781354]
# 2                                               [780788]
# 3                               [780610, 780674, 780804]
# 4       [781090, 780985, 781008, 781099, 781103, 781123]
# ...                                                  ...
# 31855  [780844, 784650, 781000, 786956, 792431, 78432...
# 31856                   [793021, 784070, 781914, 780896]
# 31857  [796036, 788347, 791911, 788664, 789423, 78414...
# 31858                           [781113, 781613, 781333]
# 31859                                   [780750, 783535]
#
#                                 prod_amount  \
# 0                                    [2, 1]
# 1                              [1, 1, 6, 1]
# 2                                       [1]
# 3                                 [3, 1, 1]
# 4                        [1, 1, 1, 1, 1, 1]
# ...                                     ...
# 31855  [1, 6, 1, 1, 1, 4, 1, 1, 1, 2, 2, 1]
# 31856                          [1, 1, 4, 1]
# 31857           [1, 1, 1, 1, 1, 1, 1, 1, 2]
# 31858                             [6, 3, 3]
# 31859                                [2, 4]
#
#                                                    asset  \
# 0                                               [56, 28]
# 1                                    [24, 114, 210, 112]
# 2                                                  [180]
# 3                                           [51, 43, 77]
# 4                               [45, 48, 53, 47, 36, 25]
# ...                                                  ...
# 31855  [41, 342, 34, 28, 14, 256, 64, 42, 35, 28, 56,...
# 31856                                 [93, 51, 432, 150]
# 31857            [93, 26, 48, 24, 109, 100, 420, 80, 28]
# 31858                                     [72, 267, 243]
# 31859                                          [28, 748]
#
#                                              sales_price
# 0                                               [48, 28]
# 1                                     [28, 119, 313, 95]
# 2                                                  [133]
# 3                                           [57, 39, 89]
# 4                               [53, 54, 64, 54, 48, 33]
# ...                                                  ...
# 31855  [43, 354, 40, 34, 19, 236, 68, 48, 39, 18, 68,...
# 31856                                 [98, 62, 460, 156]
# 31857           [99, 39, 70, 37, 149, 109, 550, 119, 36]
# 31858                                     [66, 285, 285]
# 31859                                          [18, 752]
#
# [31860 rows x 9 columns]

# %%
for idx, _ in enumerate(taf):
    for num, letter in enumerate(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K']):
        taf[idx].loc[taf[idx]['age_group'] == letter + ' ', 'age_group']= -1 - num
        if letter not in ('I', 'J', 'K'):  # występują tylko w wieku
            taf[idx].loc[taf[idx]['zipcode_area'] == letter + ' ', 'zipcode_area'] = -42 - num

# %%
for idx, _ in enumerate(taf):
    taf[idx] = taf[idx].drop(['timestamp', 'customer', 'prod_amount', 'asset', 'sales_price'], 1)

taf[0]
# Out:
#        age_group  zipcode_area  \
# 0            -10           -46
# 1             -8           -46
# 2             -7           -46
# 3             -4           -46
# 4             -4           -46
# ...          ...           ...
# 31855         -8           -48
# 31856         -3           -44
# 31857         -6           -44
# 31858         -4           -47
# 31859         -6           -45
#
#                                            prod_subclass  \
# 0                                       [130315, 120105]
# 1                       [100304, 130204, 100511, 100113]
# 2                                               [110217]
# 3                               [110411, 110401, 110117]
# 4       [130201, 130204, 110401, 130206, 120109, 120109]
# ...                                                  ...
# 31855  [110117, 130404, 130206, 110105, 110208, 76013...
# 31856                   [720221, 500205, 500202, 500201]
# 31857  [100413, 520144, 520211, 520213, 500316, 10041...
# 31858                           [100508, 100414, 100414]
# 31859                                   [110106, 560201]
#
#                                                  prod_id
# 0                                       [780611, 780783]
# 1                       [781334, 780814, 781339, 781354]
# 2                                               [780788]
# 3                               [780610, 780674, 780804]
# 4       [781090, 780985, 781008, 781099, 781103, 781123]
# ...                                                  ...
# 31855  [780844, 784650, 781000, 786956, 792431, 78432...
# 31856                   [793021, 784070, 781914, 780896]
# 31857  [796036, 788347, 791911, 788664, 789423, 78414...
# 31858                           [781113, 781613, 781333]
# 31859                                   [780750, 783535]
#
# [31860 rows x 4 columns]

# %%
taf_to_name = ['11', '12', '01', '02']

# %%
for idx, _ in enumerate(taf):
    csv = taf[idx].to_csv(sep=' ', header=False, index=False)
    csv = csv.replace('"', '').replace('[', '').replace(']', '').replace(',', '')

    with open(f"tafeng_{taf_to_name[idx]}.csv", 'w') as f:
        f.write(csv)

# %%
for idx, _ in enumerate(taf):
    curr_matrix = load_dataset(f'tafeng_{taf_to_name[idx]}.csv')
    print(curr_matrix.__repr__())
    DATASETS[f'tafeng#{idx}'] = curr_matrix
# Out:
# (31861, 798166)
# <31861x798166 sparse matrix of type '<class 'numpy.bool_'>'
# 	with 479425 stored elements in Compressed Sparse Column format>
# (26767, 797294)
# <26767x797294 sparse matrix of type '<class 'numpy.bool_'>'
# 	with 384690 stored elements in Compressed Sparse Column format>
# (29902, 798470)
# <29902x798470 sparse matrix of type '<class 'numpy.bool_'>'
# 	with 460202 stored elements in Compressed Sparse Column format>
# (31052, 797478)
# <31052x797478 sparse matrix of type '<class 'numpy.bool_'>'
# 	with 432370 stored elements in Compressed Sparse Column format>

# %%
def reverse_transform(rev_transformer, s):
    for k, v in rev_transformer.items():
        s = s.replace(str(k), str(v))
    return s

# %% [markdown]
# ### Listopad

# %%
tafeng_11_res = apriori('tafeng#0', 0.02, 0.3)
reverse_transformer = {v: k for k, v in TAFENG_TRANSFORMATORS[0].items()}
tafeng_11_res['rule'] = tafeng_11_res['rule'].map(
    lambda rule: reverse_transform(reverse_transformer, rule))

tafeng_11_res.sort_values('confidence', ascending=False)
# Out:
# doing K = 2
# 88
# doing K = 3
# 67
# doing K = 4
# 5
#                                   rule  fractional support  confidence  \
# 22         {4710421090059} -> {100508}            0.028248    1.000000
# 10         {4711080010112} -> {130206}            0.020464    1.000000
# 14         {110106} -> {4711271000014}            0.074040    0.897982
# 6          {130315} -> {4714981010038}            0.107624    0.860261
# 11  {2270022005125} -> {4973167711156}            0.027306    0.790909
# 20         {500210} -> {4710908131589}            0.030759    0.600122
# 19            {20222406} -> {20386221}            0.052760    0.465780
# 2                 {100312} -> {100205}            0.026867    0.457754
# 5               {100312} -> {20386221}            0.024011    0.409091
# 4               {130106} -> {20488109}            0.022630    0.356225
# 0          {110217} -> {4719090900058}            0.029252    0.352496
# 1        {4710076407080} -> {20488109}            0.031983    0.345541
# 21                {100201} -> {100205}            0.026616    0.344715
# 8               {120103} -> {20488109}            0.020087    0.343348
# 23              {110217} -> {20488109}            0.028216    0.340015
# 3        {8006043608007} -> {20488109}            0.056903    0.336177
# 13              {130204} -> {20488109}            0.032673    0.333227
# 18              {500201} -> {20488109}            0.027463    0.323356
# 7               {110401} -> {20488109}            0.027777    0.319264
# 16              {130206} -> {20488109}            0.029503    0.318105
# 15       {4718718501011} -> {20488109}            0.064248    0.317512
# 12              {100201} -> {20488109}            0.023477    0.304065
# 17              {100205} -> {20488109}            0.039421    0.301127
# 9        {4904511002224} -> {20488109}            0.048931    0.300154
#
#          lift  leverage
# 22  28.220549  0.027247
# 10  10.782064  0.018566
# 14  12.128283  0.067936
# 6    7.993226  0.094159
# 11  13.290693  0.025252
# 20  19.510716  0.029182
# 19   1.107727  0.005131
# 2    3.496644  0.019183
# 5    0.972908 -0.000669
# 4    1.202043  0.003804
# 0   12.050303  0.026825
# 1    1.165990  0.004553
# 21   2.633176  0.016508
# 8    1.158589  0.002750
# 23   1.147344  0.003624
# 3    1.134391  0.006741
# 13   1.124437  0.003616
# 18   1.091128  0.002294
# 7    1.077322  0.001994
# 16   1.073410  0.002018
# 15   1.071410  0.004282
# 12   1.026034  0.000596
# 17   1.016120  0.000625
# 9    1.012837  0.000620

# %% [markdown]
# ### Grudzień

# %%
tafeng_12_res = apriori('tafeng#1', 0.02, 0.3)
reverse_transformer = {v: k for k, v in TAFENG_TRANSFORMATORS[1].items()}
tafeng_12_res['rule'] = tafeng_12_res['rule'].map(
    lambda rule: reverse_transform(reverse_transformer, rule))

tafeng_12_res.sort_values('confidence', ascending=False)
# Out:
# doing K = 2
# 77
# doing K = 3
# 52
# doing K = 4
# 2
#                                           rule  fractional support  \
# 7                  {4713985863121} -> {130315}            0.028132
# 15                 {4711271000014} -> {110106}            0.095117
# 11               {20562472} -> {4714995000124}            0.030299
# 16                 {530301} -> {4710683100015}            0.022864
# 8           {4710215200022} -> {4711180102021}            0.054433
# 2                         {100312} -> {100205}            0.022079
# 20  {4711271000014} -> {4711180102021, 110106}            0.039452
# 21  {4711271000014, 110106} -> {4711180102021}            0.039452
# 6           {4711271000014} -> {4711180102021}            0.039452
# 4                  {110117} -> {4710063031106}            0.027310
# 5                  {130106} -> {4710583996008}            0.021930
# 18                        {100201} -> {100205}            0.021407
# 12               {20566043} -> {4715463024116}            0.065304
# 3                  {110401} -> {4715463024116}            0.025815
# 1                  {530101} -> {4715463024116}            0.020585
# 0                  {130206} -> {4715463024116}            0.027086
# 19          {4711038000677} -> {4715463024116}            0.029140
# 14          {4718262000213} -> {4715463024116}            0.051182
# 17                 {130204} -> {4715463024116}            0.028468
# 10                 {500201} -> {4715463024116}            0.027160
# 9                  {110117} -> {4715463024116}            0.021967
# 13                 {100205} -> {4715463024116}            0.038443
#
#     confidence       lift  leverage
# 7     1.000000  18.460000  0.026608
# 15    1.000000   9.055142  0.084613
# 11    0.808574  12.928977  0.027955
# 16    0.522184  22.838737  0.021863
# 8     0.468790   1.144170  0.006859
# 2     0.421541   3.306969  0.015403
# 20    0.414768   9.221015  0.035173
# 21    0.414768   1.012319  0.000480
# 6     0.414768   1.012319  0.000480
# 4     0.381126  13.955683  0.025353
# 5     0.369880  16.866415  0.020630
# 18    0.333527   2.616508  0.013225
# 12    0.328201   1.132667  0.007649
# 3     0.326097   1.125405  0.002877
# 1     0.324308   1.119232  0.002193
# 0     0.319947   1.104180  0.002556
# 19    0.319018   1.100975  0.002673
# 14    0.318087   1.097760  0.004558
# 17    0.314486   1.085334  0.002238
# 10    0.313227   1.080989  0.002035
# 9     0.306569   1.058012  0.001204
# 13    0.301583   1.040802  0.001507

# %% [markdown]
# ### Styczeń

# %%
tafeng_01_res = apriori('tafeng#2', 0.02, 0.3)
reverse_transformer = {v: k for k, v in TAFENG_TRANSFORMATORS[2].items()}
tafeng_01_res['rule'] = tafeng_01_res['rule'].map(
    lambda rule: reverse_transform(reverse_transformer, rule))

tafeng_01_res.sort_values('confidence', ascending=False)
# Out:
# doing K = 2
# 99
# doing K = 3
# 47
# doing K = 4
# 1
#                                   rule  fractional support  confidence  \
# 2          {4712425010712} -> {500201}            0.028326    1.000000
# 3          {4712425010255} -> {500210}            0.020701    1.000000
# 8          {4714981010038} -> {130315}            0.024079    1.000000
# 7       {76174644548} -> {41554616033}            0.029998    0.810298
# 4          {110217} -> {4719090900065}            0.054913    0.448022
# 0          {120103} -> {4710011401128}            0.020601    0.321503
# 6   {8888240001160} -> {4711629910521}            0.060966    0.314094
# 9   {9300697100139} -> {4711629910521}            0.050632    0.306478
# 10         {110401} -> {4711629910521}            0.021905    0.306218
# 1          {110217} -> {4711629910521}            0.037489    0.305866
# 5   {4715833514162} -> {4711629910521}            0.025048    0.305216
#
#          lift  leverage
# 2   10.949103  0.025739
# 3   23.324493  0.019813
# 8   20.396999  0.022898
# 7   12.368317  0.027573
# 4    8.158799  0.048182
# 0   15.606472  0.019281
# 6    1.140502  0.007511
# 9    1.112847  0.005134
# 10   1.111904  0.002205
# 1    1.110627  0.003734
# 5    1.108266  0.002447

# %% [markdown]
# ### Luty

# %%
tafeng_02_res = apriori('tafeng#3', 0.02, 0.3)
reverse_transformer = {v: k for k, v in TAFENG_TRANSFORMATORS[3].items()}
tafeng_02_res['rule'] = tafeng_02_res['rule'].map(
    lambda rule: reverse_transform(reverse_transformer, rule))

tafeng_02_res.sort_values('confidence', ascending=False)
# Out:
# doing K = 2
# 87
# doing K = 3
# 58
# doing K = 4
# 4
#                                   rule  fractional support  confidence  \
# 0          {4711271000014} -> {110106}            0.027985    1.000000
# 6          {4714981010038} -> {130315}            0.122794    1.000000
# 11         {4710114128038} -> {500201}            0.022704    1.000000
# 13         {4711856000088} -> {110501}            0.020611    1.000000
# 14         {4711856000125} -> {110501}            0.028919    1.000000
# 8   {4710223169137} -> {4710076115473}            0.030529    0.807496
# 2                 {100312} -> {100205}            0.032043    0.494779
# 1          {500202} -> {4710908110232}            0.022800    0.381466
# 10         {500202} -> {4710114362029}            0.020578    0.344289
# 9          {110217} -> {4710265849066}            0.027599    0.342116
# 7   {4710105027326} -> {4714219794303}            0.027309    0.313609
# 4   {4973167481370} -> {4714219794303}            0.050432    0.310714
# 12         {110401} -> {4714219794303}            0.023445    0.308344
# 3   {4715833010824} -> {4714219794303}            0.061928    0.308222
# 5          {130206} -> {4714219794303}            0.027277    0.301853
#
#          lift  leverage
# 0   22.534107  0.026743
# 6    6.963893  0.105161
# 11  10.385284  0.020518
# 13  22.501449  0.019695
# 14  22.501449  0.027634
# 8   12.663817  0.028119
# 2    4.040997  0.024114
# 1   16.730603  0.021438
# 10  16.730603  0.019348
# 9   12.396008  0.025372
# 7    1.156693  0.003699
# 4    1.146015  0.006426
# 12   1.137272  0.002830
# 3    1.136824  0.007453
# 5    1.113332  0.002777

# %% [markdown]
# ## Scratchpad

# %%
retail_frequent_itemsets = gen_frequent_itemsets(retail_matrix, 0.02)
retail_frequent_itemsets
# Out:
# doing K = 2
# 355
# doing K = 3
# 388
# doing K = 4
# 169
# doing K = 5
# 29
# doing K = 6
# 4
# [{2},
#  {9},
#  {10},
#  {11},
#  {12},
#  {15},
#  {18},
#  {19},
#  {23},
#  {30},
#  {31},
#  {32},
#  {36},
#  {37},
#  {38},
#  {39},
#  {41},
#  {45},
#  {47},
#  {48},
#  {49},
#  {52},
#  {53},
#  {55},
#  {56},
#  {60},
#  {62},
#  {65},
#  {76},
#  {78},
#  {79},
#  {80},
#  {89},
#  {94},
#  {96},
#  {101},
#  {103},
#  {105},
#  {107},
#  {110},
#  {117},
#  {123},
#  {136},
#  {147},
#  {150},
#  {155},
#  {156},
#  {161},
#  {164},
#  {170},
#  {175},
#  {176},
#  {178},
#  {179},
#  {185},
#  {186},
#  {195},
#  {201},
#  {208},
#  {209},
#  {225},
#  {229},
#  {232},
#  {237},
#  {242},
#  {246},
#  {248},
#  {249},
#  {251},
#  {255},
#  {258},
#  {259},
#  {260},
#  {261},
#  {264},
#  {267},
#  {269},
#  {270},
#  {271},
#  {272},
#  {279},
#  {281},
#  {286},
#  {297},
#  {301},
#  {310},
#  {319},
#  {334},
#  {338},
#  {340},
#  {341},
#  {345},
#  {346},
#  {351},
#  {352},
#  {365},
#  {370},
#  {371},
#  {374},
#  {379},
#  {384},
#  {389},
#  {390},
#  {396},
#  {398},
#  {405},
#  {407},
#  {408},
#  {413},
#  {415},
#  {418},
#  {420},
#  {424},
#  {425},
#  {426},
#  {432},
#  {438},
#  {441},
#  {449},
#  {464},
#  {475},
#  {479},
#  {488},
#  {490},
#  {497},
#  {514},
#  {522},
#  {533},
#  {535},
#  {544},
#  {547},
#  {548},
#  {549},
#  {570},
#  {571},
#  {581},
#  {589},
#  {591},
#  {592},
#  {604},
#  {610},
#  {623},
#  {640},
#  {643},
#  {649},
#  {653},
#  {664},
#  {675},
#  {677},
#  {681},
#  {694},
#  {703},
#  {704},
#  {715},
#  {727},
#  {730},
#  {734},
#  {740},
#  {766},
#  {768},
#  {772},
#  {783},
#  {785},
#  {789},
#  {790},
#  {793},
#  {798},
#  {806},
#  {808},
#  {809},
#  {812},
#  {817},
#  {824},
#  {829},
#  {830},
#  {831},
#  {840},
#  {842},
#  {846},
#  {855},
#  {856},
#  {865},
#  {878},
#  {885},
#  {903},
#  {910},
#  {913},
#  {916},
#  {947},
#  {956},
#  {961},
#  {976},
#  {978},
#  {979},
#  {984},
#  {993},
#  {1000},
#  {1003},
#  {1004},
#  {1020},
#  {1027},
#  {1043},
#  {1046},
#  {1052},
#  {1062},
#  {1066},
#  {1067},
#  {1081},
#  {1082},
#  {1103},
#  {1113},
#  {1121},
#  {1126},
#  {1135},
#  {1144},
#  {1146},
#  {1158},
#  {1185},
#  {1198},
#  {1214},
#  {1239},
#  {1257},
#  {1277},
#  {1308},
#  {1313},
#  {1327},
#  {1344},
#  {1355},
#  {1360},
#  {1361},
#  {1393},
#  {1404},
#  {1417},
#  {1425},
#  {1435},
#  {1444},
#  {1479},
#  {1481},
#  {1486},
#  {1513},
#  {1543},
#  {1557},
#  {1562},
#  {1578},
#  {1585},
#  {1600},
#  {1619},
#  {1638},
#  {1659},
#  {1677},
#  {1693},
#  {1704},
#  {1714},
#  {1715},
#  {1783},
#  {1814},
#  {1859},
#  {1867},
#  {1872},
#  {1930},
#  {1973},
#  {1986},
#  {1987},
#  {2015},
#  {2046},
#  {2051},
#  {2056},
#  {2065},
#  {2080},
#  {2091},
#  {2115},
#  {2118},
#  {2135},
#  {2168},
#  {2184},
#  {2187},
#  {2199},
#  {2208},
#  {2238},
#  {2241},
#  {2254},
#  {2284},
#  {2325},
#  {2329},
#  {2343},
#  {2353},
#  {2383},
#  {2399},
#  {2437},
#  {2468},
#  {2492},
#  {2505},
#  {2515},
#  {2523},
#  {2552},
#  {2626},
#  {2633},
#  {2673},
#  {2775},
#  {2879},
#  {2894},
#  {2958},
#  {2987},
#  {2991},
#  {3270},
#  {3361},
#  {3502},
#  {3510},
#  {3616},
#  {3799},
#  {3827},
#  {3904},
#  {4336},
#  {4650},
#  {4698},
#  {4883},
#  {5051},
#  {7205},
#  {7975},
#  {8691},
#  {8978},
#  {8985},
#  {9501},
#  {9555},
#  {10442},
#  {10444},
#  {10446},
#  {10490},
#  {10491},
#  {10515},
#  {10525},
#  {10653},
#  {10656},
#  {12925},
#  {12929},
#  {12933},
#  {12935},
#  {12943},
#  {12946},
#  {12951},
#  {12959},
#  {13041},
#  {13189},
#  {13334},
#  {13443},
#  {14098},
#  {14099},
#  {14933},
#  {15618},
#  {15832},
#  {16010},
#  {16011},
#  {16217},
#  {16430},
#  {16431},
#  frozenset({48, 101}),
#  frozenset({39, 865}),
#  frozenset({48, 675}),
#  frozenset({38, 390}),
#  frozenset({48, 259}),
#  frozenset({48, 1578}),
#  frozenset({39, 1715}),
#  frozenset({39, 297}),
#  frozenset({41, 237}),
#  frozenset({48, 589}),
#  frozenset({39, 806}),
#  frozenset({39, 878}),
#  frozenset({39, 592}),
#  frozenset({38, 2238}),
#  frozenset({48, 10515}),
#  frozenset({38, 310}),
#  frozenset({48, 156}),
#  frozenset({41, 16010}),
#  frozenset({32, 271}),
#  frozenset({32, 79}),
#  frozenset({48, 10446}),
#  frozenset({48, 4336}),
#  frozenset({39, 581}),
#  frozenset({39, 105}),
#  frozenset({11, 39}),
#  frozenset({39, 107}),
#  frozenset({48, 1393}),
#  frozenset({39, 179}),
#  frozenset({39, 961}),
#  frozenset({38, 840}),
#  frozenset({39, 45}),
#  frozenset({39, 979}),
#  frozenset({48, 548}),
#  frozenset({48, 681}),
#  frozenset({39, 4336}),
#  frozenset({39, 675}),
#  frozenset({48, 374}),
#  frozenset({39, 267}),
#  frozenset({48, 16217}),
#  frozenset({32, 225}),
#  frozenset({39, 12946}),
#  frozenset({48, 13041}),
#  frozenset({48, 956}),
#  frozenset({38, 270}),
#  frozenset({39, 53}),
#  frozenset({48, 389}),
#  frozenset({10, 39}),
#  frozenset({39, 413}),
#  frozenset({48, 123}),
#  frozenset({32, 475}),
#  frozenset({48, 772}),
#  frozenset({48, 1146}),
#  frozenset({38, 89}),
#  frozenset({48, 201}),
#  frozenset({39, 2284}),
#  frozenset({48, 12925}),
#  frozenset({39, 2958}),
#  frozenset({48, 1135}),
#  frozenset({39, 269}),
#  frozenset({48, 16011}),
#  frozenset({48, 809}),
#  frozenset({48, 272}),
#  frozenset({39, 147}),
#  frozenset({39, 56}),
#  frozenset({39, 426}),
#  frozenset({39, 10446}),
#  frozenset({39, 101}),
#  frozenset({48, 581}),
#  frozenset({39, 271}),
#  frozenset({48, 1344}),
#  frozenset({48, 260}),
#  frozenset({37, 39}),
#  frozenset({38, 438}),
#  frozenset({48, 117}),
#  frozenset({39, 15618}),
#  frozenset({39, 55}),
#  frozenset({32, 270}),
#  frozenset({41, 110}),
#  frozenset({41, 2238}),
#  frozenset({39, 1327}),
#  frozenset({37, 48}),
#  frozenset({38, 271}),
#  frozenset({48, 301}),
#  frozenset({48, 249}),
#  frozenset({39, 2383}),
#  frozenset({48, 522}),
#  frozenset({41, 65}),
#  frozenset({32, 48}),
#  frozenset({39, 789}),
#  frozenset({48, 12929}),
#  frozenset({48, 441}),
#  frozenset({31, 48}),
#  frozenset({38, 790}),
#  frozenset({48, 338}),
#  frozenset({48, 237}),
#  frozenset({48, 76}),
#  frozenset({48, 1715}),
#  frozenset({39, 535}),
#  frozenset({39, 186}),
#  frozenset({48, 533}),
#  frozenset({41, 255}),
#  frozenset({39, 41}),
#  frozenset({39, 374}),
#  frozenset({39, 272}),
#  frozenset({39, 65}),
#  frozenset({39, 310}),
#  frozenset({48, 185}),
#  frozenset({39, 1435}),
#  frozenset({18, 48}),
#  frozenset({39, 12925}),
#  frozenset({39, 1239}),
#  frozenset({39, 1600}),
#  frozenset({48, 783}),
#  frozenset({48, 271}),
#  frozenset({48, 78}),
#  frozenset({39, 1393}),
#  frozenset({39, 464}),
#  frozenset({39, 681}),
#  frozenset({45, 48}),
#  frozenset({48, 677}),
#  frozenset({48, 65}),
#  frozenset({38, 237}),
#  frozenset({39, 89}),
#  frozenset({48, 258}),
#  frozenset({38, 281}),
#  frozenset({32, 101}),
#  frozenset({39, 270}),
#  frozenset({38, 48}),
#  frozenset({39, 10515}),
#  frozenset({9, 39}),
#  frozenset({48, 334}),
#  frozenset({48, 649}),
#  frozenset({41, 533}),
#  frozenset({48, 264}),
#  frozenset({39, 913}),
#  frozenset({48, 379}),
#  frozenset({48, 976}),
#  frozenset({48, 664}),
#  frozenset({48, 79}),
#  frozenset({39, 13041}),
#  frozenset({48, 16010}),
#  frozenset({48, 3270}),
#  frozenset({39, 15832}),
#  frozenset({39, 301}),
#  frozenset({41, 79}),
#  frozenset({39, 2046}),
#  frozenset({41, 16217}),
#  frozenset({39, 549}),
#  frozenset({48, 2118}),
#  frozenset({32, 39}),
#  frozenset({48, 269}),
#  frozenset({48, 242}),
#  frozenset({48, 407}),
#  frozenset({48, 740}),
#  frozenset({39, 1783}),
#  frozenset({38, 105}),
#  frozenset({48, 161}),
#  frozenset({32, 310}),
#  frozenset({39, 703}),
#  frozenset({39, 604}),
#  frozenset({41, 1146}),
#  frozenset({39, 389}),
#  frozenset({48, 488}),
#  frozenset({38, 47}),
#  frozenset({39, 916}),
#  frozenset({48, 865}),
#  frozenset({39, 1872}),
#  frozenset({48, 413}),
#  frozenset({38, 370}),
#  frozenset({48, 89}),
#  frozenset({48, 2437}),
#  frozenset({48, 251}),
#  frozenset({39, 441}),
#  frozenset({38, 65}),
#  frozenset({11, 48}),
#  frozenset({41, 147}),
#  frozenset({39, 396}),
#  frozenset({39, 425}),
#  frozenset({32, 2238}),
#  frozenset({16430, 16431}),
#  frozenset({39, 117}),
#  frozenset({39, 103}),
#  frozenset({48, 1144}),
#  frozenset({48, 425}),
#  frozenset({39, 407}),
#  frozenset({39, 405}),
#  frozenset({39, 1004}),
#  frozenset({41, 15832}),
#  frozenset({48, 270}),
#  frozenset({39, 544}),
#  frozenset({41, 413}),
#  frozenset({48, 405}),
#  frozenset({39, 334}),
#  frozenset({39, 1198}),
#  frozenset({48, 570}),
#  frozenset({48, 1239}),
#  frozenset({39, 1344}),
#  frozenset({38, 170}),
#  frozenset({39, 60}),
#  frozenset({39, 260}),
#  frozenset({39, 1814}),
#  frozenset({48, 14098}),
#  frozenset({39, 338}),
#  frozenset({270, 271}),
#  frozenset({36, 41}),
#  frozenset({39, 175}),
#  frozenset({48, 592}),
#  frozenset({39, 475}),
#  frozenset({41, 13041}),
#  frozenset({30, 39}),
#  frozenset({39, 570}),
#  frozenset({32, 170}),
#  frozenset({39, 14098}),
#  frozenset({48, 279}),
#  frozenset({48, 186}),
#  frozenset({48, 105}),
#  frozenset({39, 242}),
#  frozenset({48, 464}),
#  frozenset({48, 225}),
#  frozenset({39, 1043}),
#  frozenset({39, 589}),
#  frozenset({48, 812}),
#  frozenset({48, 535}),
#  frozenset({32, 147}),
#  frozenset({48, 286}),
#  frozenset({48, 1067}),
#  frozenset({39, 156}),
#  frozenset({48, 2238}),
#  frozenset({38, 286}),
#  frozenset({48, 766}),
#  frozenset({48, 3616}),
#  frozenset({41, 270}),
#  frozenset({32, 65}),
#  frozenset({48, 1872}),
#  frozenset({39, 201}),
#  frozenset({48, 2958}),
#  frozenset({38, 225}),
#  frozenset({39, 438}),
#  frozenset({16010, 16011}),
#  frozenset({32, 438}),
#  frozenset({39, 279}),
#  frozenset({48, 340}),
#  frozenset({48, 2199}),
#  frozenset({32, 110}),
#  frozenset({39, 1986}),
#  frozenset({39, 249}),
#  frozenset({39, 16010}),
#  frozenset({39, 824}),
#  frozenset({39, 649}),
#  frozenset({32, 89}),
#  frozenset({48, 1783}),
#  frozenset({41, 438}),
#  frozenset({48, 229}),
#  frozenset({41, 1327}),
#  frozenset({39, 783}),
#  frozenset({23, 48}),
#  frozenset({48, 147}),
#  frozenset({39, 150}),
#  frozenset({48, 179}),
#  frozenset({39, 1693}),
#  frozenset({19, 48}),
#  frozenset({48, 175}),
#  frozenset({39, 677}),
#  frozenset({39, 533}),
#  frozenset({48, 449}),
#  frozenset({39, 258}),
#  frozenset({32, 36}),
#  frozenset({39, 809}),
#  frozenset({48, 15832}),
#  frozenset({36, 38}),
#  frozenset({39, 371}),
#  frozenset({39, 479}),
#  frozenset({39, 225}),
#  frozenset({32, 1046}),
#  frozenset({38, 371}),
#  frozenset({48, 310}),
#  frozenset({48, 1435}),
#  frozenset({39, 3270}),
#  frozenset({39, 12929}),
#  frozenset({32, 1146}),
#  frozenset({37, 38}),
#  frozenset({39, 264}),
#  frozenset({9, 48}),
#  frozenset({39, 16217}),
#  frozenset({39, 237}),
#  frozenset({48, 1327}),
#  frozenset({39, 449}),
#  frozenset({39, 664}),
#  frozenset({48, 150}),
#  frozenset({48, 396}),
#  frozenset({10, 48}),
#  frozenset({48, 806}),
#  frozenset({41, 225}),
#  frozenset({41, 271}),
#  frozenset({48, 703}),
#  frozenset({39, 251}),
#  frozenset({39, 185}),
#  frozenset({39, 812}),
#  frozenset({39, 286}),
#  frozenset({48, 371}),
#  frozenset({39, 2238}),
#  frozenset({48, 824}),
#  frozenset({48, 2383}),
#  frozenset({39, 155}),
#  frozenset({39, 548}),
#  frozenset({39, 76}),
#  frozenset({48, 208}),
#  frozenset({48, 438}),
#  frozenset({39, 340}),
#  frozenset({39, 110}),
#  frozenset({19, 39}),
#  frozenset({39, 161}),
#  frozenset({36, 39}),
#  frozenset({48, 1600}),
#  frozenset({48, 103}),
#  frozenset({39, 488}),
#  frozenset({48, 544}),
#  frozenset({38, 475}),
#  frozenset({39, 16011}),
#  frozenset({39, 379}),
#  frozenset({32, 41}),
#  frozenset({39, 976}),
#  frozenset({39, 170}),
#  frozenset({38, 39}),
#  frozenset({38, 110}),
#  frozenset({48, 1198}),
#  frozenset({23, 39}),
#  frozenset({38, 56}),
#  frozenset({32, 237}),
#  frozenset({48, 107}),
#  frozenset({48, 549}),
#  frozenset({39, 1578}),
#  frozenset({48, 475}),
#  frozenset({39, 8978}),
#  frozenset({48, 49}),
#  frozenset({39, 261}),
#  frozenset({39, 1067}),
#  frozenset({39, 522}),
#  frozenset({48, 604}),
#  frozenset({225, 271}),
#  frozenset({39, 885}),
#  frozenset({41, 310}),
#  frozenset({18, 39}),
#  frozenset({41, 101}),
#  frozenset({41, 475}),
#  frozenset({39, 259}),
#  frozenset({39, 740}),
#  frozenset({225, 2238}),
#  frozenset({48, 1986}),
#  frozenset({48, 255}),
#  frozenset({41, 48}),
#  frozenset({39, 48}),
#  frozenset({39, 229}),
#  frozenset({39, 772}),
#  frozenset({39, 1146}),
#  frozenset({38, 41}),
#  frozenset({39, 3616}),
#  frozenset({48, 261}),
#  frozenset({39, 766}),
#  frozenset({48, 60}),
#  frozenset({31, 39}),
#  frozenset({39, 255}),
#  frozenset({39, 79}),
#  frozenset({48, 267}),
#  frozenset({48, 1814}),
#  frozenset({39, 790}),
#  frozenset({41, 170}),
#  frozenset({41, 89}),
#  frozenset({48, 1004}),
#  frozenset({32, 38}),
#  frozenset({36, 48}),
#  frozenset({38, 55}),
#  frozenset({39, 1144}),
#  frozenset({38, 3904}),
#  frozenset({39, 1135}),
#  frozenset({39, 78}),
#  frozenset({38, 1327}),
#  frozenset({38, 101}),
#  frozenset({39, 123}),
#  frozenset({48, 479}),
#  frozenset({48, 8978}),
#  frozenset({39, 420}),
#  frozenset({39, 49}),
#  frozenset({39, 956}),
#  frozenset({48, 170}),
#  frozenset({48, 110}),
#  frozenset({39, 2199}),
#  frozenset({48, 789}),
#  frozenset({39, 16010, 16011}),
#  frozenset({38, 48, 371}),
#  frozenset({39, 48, 249}),
#  frozenset({39, 48, 78}),
#  frozenset({39, 48, 533}),
#  frozenset({39, 48, 123}),
#  frozenset({39, 48, 117}),
#  frozenset({32, 48, 65}),
#  frozenset({39, 48, 740}),
#  frozenset({39, 41, 147}),
#  frozenset({32, 39, 225}),
#  frozenset({36, 38, 48}),
#  frozenset({36, 39, 48}),
#  frozenset({38, 48, 170}),
#  frozenset({39, 48, 592}),
#  frozenset({39, 48, 179}),
#  frozenset({37, 39, 48}),
#  frozenset({38, 39, 170}),
#  frozenset({39, 48, 310}),
#  frozenset({39, 45, 48}),
#  frozenset({39, 41, 65}),
#  frozenset({41, 48, 170}),
#  frozenset({39, 48, 405}),
#  frozenset({38, 39, 105}),
#  frozenset({38, 39, 41}),
#  frozenset({48, 270, 271}),
#  frozenset({39, 48, 175}),
#  frozenset({38, 39, 371}),
#  frozenset({39, 48, 10515}),
#  frozenset({11, 39, 48}),
#  frozenset({41, 48, 89}),
#  frozenset({41, 48, 475}),
#  frozenset({41, 48, 79}),
#  frozenset({39, 41, 1327}),
#  frozenset({41, 48, 271}),
#  frozenset({39, 48, 110}),
#  frozenset({39, 41, 237}),
#  frozenset({39, 48, 1578}),
#  frozenset({39, 48, 79}),
#  frozenset({39, 48, 783}),
#  frozenset({38, 41, 110}),
#  frozenset({38, 48, 110}),
#  frozenset({39, 48, 2958}),
#  frozenset({39, 48, 3270}),
#  frozenset({41, 48, 101}),
#  frozenset({41, 48, 310}),
#  frozenset({39, 48, 604}),
#  frozenset({36, 39, 41}),
#  frozenset({39, 48, 1004}),
#  frozenset({39, 48, 264}),
#  frozenset({39, 48, 766}),
#  frozenset({39, 48, 286}),
#  frozenset({32, 36, 38}),
#  frozenset({41, 48, 65}),
#  frozenset({39, 48, 301}),
#  frozenset({39, 48, 156}),
#  frozenset({31, 39, 48}),
#  frozenset({41, 48, 110}),
#  frozenset({9, 39, 48}),
#  frozenset({32, 39, 170}),
#  frozenset({39, 48, 225}),
#  frozenset({39, 48, 170}),
#  frozenset({32, 39, 237}),
#  frozenset({39, 48, 101}),
#  frozenset({38, 41, 48}),
#  frozenset({39, 48, 270}),
#  frozenset({39, 48, 677}),
#  frozenset({38, 39, 56}),
#  frozenset({32, 48, 310}),
#  frozenset({39, 41, 16217}),
#  frozenset({32, 39, 89}),
#  frozenset({39, 48, 14098}),
#  frozenset({39, 48, 271}),
#  frozenset({39, 48, 334}),
#  frozenset({39, 41, 89}),
#  frozenset({39, 41, 310}),
#  frozenset({36, 38, 39}),
#  frozenset({39, 48, 76}),
#  frozenset({39, 48, 522}),
#  frozenset({32, 38, 39}),
#  frozenset({39, 48, 255}),
#  frozenset({39, 48, 1146}),
#  frozenset({32, 38, 110}),
#  frozenset({39, 41, 225}),
#  frozenset({39, 41, 110}),
#  frozenset({39, 48, 237}),
#  frozenset({37, 38, 48}),
#  frozenset({39, 48, 438}),
#  frozenset({38, 48, 89}),
#  frozenset({38, 48, 237}),
#  frozenset({32, 48, 225}),
#  frozenset({38, 39, 310}),
#  frozenset({41, 48, 237}),
#  frozenset({39, 41, 16010}),
#  frozenset({39, 48, 548}),
#  frozenset({39, 41, 271}),
#  frozenset({39, 41, 170}),
#  frozenset({39, 48, 1327}),
#  frozenset({38, 48, 105}),
#  frozenset({38, 39, 89}),
#  frozenset({38, 39, 48}),
#  frozenset({32, 39, 48}),
#  frozenset({48, 16010, 16011}),
#  frozenset({38, 39, 110}),
#  frozenset({39, 41, 270}),
#  frozenset({39, 48, 185}),
#  frozenset({39, 48, 824}),
#  frozenset({39, 41, 475}),
#  frozenset({32, 39, 41}),
#  frozenset({32, 38, 41}),
#  frozenset({37, 38, 39}),
#  frozenset({39, 41, 48}),
#  frozenset({39, 48, 12925}),
#  frozenset({32, 41, 48}),
#  frozenset({39, 48, 2238}),
#  frozenset({38, 39, 65}),
#  frozenset({19, 39, 48}),
#  frozenset({39, 48, 479}),
#  frozenset({41, 48, 225}),
#  frozenset({38, 39, 225}),
#  frozenset({18, 39, 48}),
#  frozenset({39, 41, 79}),
#  frozenset({32, 39, 65}),
#  frozenset({32, 39, 310}),
#  frozenset({39, 48, 1393}),
#  frozenset({39, 48, 1814}),
#  frozenset({32, 48, 237}),
#  frozenset({38, 39, 286}),
#  frozenset({39, 48, 201}),
#  frozenset({39, 48, 229}),
#  frozenset({39, 48, 338}),
#  frozenset({38, 39, 790}),
#  frozenset({39, 48, 161}),
#  frozenset({32, 38, 170}),
#  frozenset({39, 48, 570}),
#  frozenset({39, 48, 16217}),
#  frozenset({39, 41, 1146}),
#  frozenset({39, 41, 2238}),
#  frozenset({38, 41, 170}),
#  frozenset({38, 48, 225}),
#  frozenset({39, 48, 89}),
#  frozenset({41, 48, 2238}),
#  frozenset({39, 48, 549}),
#  frozenset({38, 48, 286}),
#  frozenset({39, 41, 438}),
#  frozenset({38, 39, 55}),
#  frozenset({39, 48, 1135}),
#  frozenset({39, 48, 16010}),
#  frozenset({39, 48, 258}),
#  frozenset({39, 48, 60}),
#  frozenset({39, 48, 65}),
#  frozenset({32, 38, 48}),
#  frozenset({39, 48, 413}),
#  frozenset({39, 48, 544}),
#  frozenset({39, 48, 649}),
#  frozenset({39, 48, 589}),
#  frozenset({39, 48, 49}),
#  frozenset({36, 41, 48}),
#  frozenset({39, 48, 475}),
#  frozenset({38, 39, 237}),
#  frozenset({38, 48, 65}),
#  frozenset({39, 48, 15832}),
#  frozenset({32, 48, 89}),
#  frozenset({39, 270, 271}),
#  frozenset({36, 38, 41}),
#  frozenset({39, 48, 956}),
#  frozenset({39, 48, 13041}),
#  frozenset({39, 41, 101}),
#  frozenset({39, 48, 147}),
#  frozenset({38, 39, 41, 110}),
#  frozenset({38, 39, 48, 170}),
#  frozenset({38, 39, 48, 225}),
#  frozenset({39, 41, 48, 170}),
#  frozenset({36, 38, 41, 48}),
#  frozenset({36, 39, 41, 48}),
#  frozenset({39, 41, 48, 89}),
#  frozenset({39, 41, 48, 65}),
#  frozenset({39, 41, 48, 475}),
#  frozenset({32, 39, 48, 65}),
#  frozenset({39, 41, 48, 310}),
#  frozenset({32, 39, 48, 89}),
#  frozenset({39, 41, 48, 110}),
#  frozenset({38, 39, 48, 89}),
#  frozenset({38, 39, 48, 237}),
#  frozenset({32, 39, 41, 48}),
#  frozenset({32, 38, 39, 48}),
#  frozenset({38, 41, 48, 110}),
#  frozenset({38, 39, 48, 286}),
#  frozenset({36, 38, 39, 41}),
#  frozenset({36, 38, 39, 48}),
#  frozenset({38, 39, 41, 170}),
#  frozenset({38, 41, 48, 170}),
#  frozenset({38, 39, 41, 48}),
#  frozenset({32, 38, 41, 48}),
#  frozenset({37, 38, 39, 48}),
#  frozenset({39, 41, 48, 225}),
#  frozenset({32, 38, 39, 41}),
#  frozenset({38, 39, 48, 110}),
#  frozenset({38, 39, 41, 48, 170}),
#  frozenset({36, 38, 39, 41, 48}),
#  frozenset({32, 38, 39, 41, 48}),
#  frozenset({38, 39, 41, 48, 110})]

# %%
rules = gen_association_rules('retail', retail_frequent_itemsets, 0.3)
