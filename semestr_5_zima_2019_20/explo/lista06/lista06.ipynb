# %% [markdown]
# # Zadanie 1.

# %% [markdown]
# ## Implementacja APRIORI i jego komponentów

# %%
import functools
import itertools

import numpy as np
import pandas as pd
import scipy.sparse

# %%
def load_dataset(filename):
    rows = []
    with open(filename) as dataset:
        for line in dataset:
            rows.append([int(item) for item in line.split()])
    # wiersz 0 i kolumna 0 być może pozostaną puste, trudno
    matrix = scipy.sparse.lil_matrix(
        (1+len(rows), 1+max([max([v for v in r]) for r in rows])), dtype='?')
    print(matrix.shape)
    for idx, r in enumerate(rows):
        matrix[idx, r] = True
    return matrix.tocsc()

# %%
retail_matrix = load_dataset('retail.dat')
# Out:
# (88163, 16470)

# %%
retail_matrix[:20]
# Out:
# <20x16470 sparse matrix of type '<class 'numpy.bool_'>'
# 	with 152 stored elements in Compressed Sparse Column format>

# %%
@functools.lru_cache(maxsize=42_000_000)
def indices_containing(matrix_name, item):
    # TODO
    return set(retail_matrix[:, item].nonzero()[0].tolist())

# %%
def support(matrix, itemset):
    first_element = True
    indices = set()
    for item in itemset:
        this_item_indices = indices_containing('retail', item)
        indices = this_item_indices if first_element else indices & this_item_indices
        first_element = False
    return len(indices)

# %%
def gen_frequent_itemsets(matrix, min_supp):
    min_supp = min_supp if min_supp == round(min_supp) else min_supp * matrix.shape[1]
    sets = {}
    sets[1] = [
        {col}
        for col in range(matrix.shape[1]) if support(matrix, {col}) > min_supp
    ]
    K = 2
    while sets[K-1]:
        print(f'doing K = {K}')
        print(len(sets[K-1]))
        sets[K] = set([
            frozenset(oldset | {newelem})
            for newelem in
                functools.reduce(lambda s1, s2: s1 | s2, sets[K-1])  # flatten
            for oldset in sets[K-1]
        ])
        sets[K] = list(filter(
            lambda newset: 
                support(matrix, newset) > min_supp
                and len(newset) == K,
            sets[K]))
        K += 1
    
    return functools.reduce(lambda s1, s2: s1 + s2, sets.values())

# %%
retail_frequent_itemsets = gen_frequent_itemsets(retail_matrix, 0.05)
# Out:
# doing K = 2
# 79
# doing K = 3
# 65
# doing K = 4
# 26
# doing K = 5
# 6

# %%
retail_frequent_itemsets
# Out:
# [{9},
#  {18},
#  {19},
#  {31},
#  {32},
#  {36},
#  {37},
#  {38},
#  {39},
#  {41},
#  {45},
#  {48},
#  {49},
#  {60},
#  {65},
#  {76},
#  {78},
#  {79},
#  {89},
#  {101},
#  {110},
#  {117},
#  {123},
#  {147},
#  {156},
#  {161},
#  {170},
#  {175},
#  {179},
#  {185},
#  {201},
#  {225},
#  {237},
#  {242},
#  {249},
#  {255},
#  {258},
#  {264},
#  {270},
#  {271},
#  {286},
#  {301},
#  {310},
#  {338},
#  {389},
#  {405},
#  {413},
#  {438},
#  {475},
#  {479},
#  {522},
#  {533},
#  {544},
#  {548},
#  {549},
#  {589},
#  {592},
#  {604},
#  {649},
#  {677},
#  {740},
#  {783},
#  {824},
#  {956},
#  {1004},
#  {1146},
#  {1327},
#  {1393},
#  {1578},
#  {2238},
#  {2958},
#  {3270},
#  {10515},
#  {12925},
#  {13041},
#  {14098},
#  {15832},
#  {16010},
#  {16217},
#  frozenset({39, 438}),
#  frozenset({48, 101}),
#  frozenset({48, 270}),
#  frozenset({39, 185}),
#  frozenset({39, 12925}),
#  frozenset({39, 533}),
#  frozenset({36, 48}),
#  frozenset({48, 475}),
#  frozenset({36, 38}),
#  frozenset({48, 271}),
#  frozenset({48, 78}),
#  frozenset({41, 65}),
#  frozenset({32, 48}),
#  frozenset({48, 79}),
#  frozenset({48, 255}),
#  frozenset({39, 225}),
#  frozenset({39, 2238}),
#  frozenset({41, 48}),
#  frozenset({39, 48}),
#  frozenset({48, 413}),
#  frozenset({48, 49}),
#  frozenset({48, 310}),
#  frozenset({39, 1146}),
#  frozenset({38, 41}),
#  frozenset({48, 89}),
#  frozenset({38, 170}),
#  frozenset({32, 41}),
#  frozenset({48, 225}),
#  frozenset({39, 60}),
#  frozenset({39, 16010}),
#  frozenset({39, 413}),
#  frozenset({48, 65}),
#  frozenset({39, 101}),
#  frozenset({39, 255}),
#  frozenset({48, 237}),
#  frozenset({39, 89}),
#  frozenset({37, 38}),
#  frozenset({39, 271}),
#  frozenset({39, 170}),
#  frozenset({39, 79}),
#  frozenset({48, 438}),
#  frozenset({39, 110}),
#  frozenset({39, 270}),
#  frozenset({48, 533}),
#  frozenset({39, 237}),
#  frozenset({48, 2238}),
#  frozenset({38, 48}),
#  frozenset({39, 475}),
#  frozenset({38, 286}),
#  frozenset({48, 1327}),
#  frozenset({39, 41}),
#  frozenset({38, 39}),
#  frozenset({48, 147}),
#  frozenset({48, 170}),
#  frozenset({9, 39}),
#  frozenset({32, 39}),
#  frozenset({38, 110}),
#  frozenset({48, 110}),
#  frozenset({41, 225}),
#  frozenset({39, 65}),
#  frozenset({39, 310}),
#  frozenset({36, 39}),
#  frozenset({39, 1327}),
#  frozenset({39, 147}),
#  frozenset({32, 38}),
#  frozenset({36, 38, 48}),
#  frozenset({39, 48, 271}),
#  frozenset({39, 41, 48}),
#  frozenset({36, 39, 48}),
#  frozenset({36, 38, 39}),
#  frozenset({32, 41, 48}),
#  frozenset({38, 48, 110}),
#  frozenset({39, 48, 225}),
#  frozenset({39, 48, 170}),
#  frozenset({39, 48, 101}),
#  frozenset({38, 41, 48}),
#  frozenset({39, 48, 475}),
#  frozenset({38, 39, 41}),
#  frozenset({38, 48, 170}),
#  frozenset({32, 38, 39}),
#  frozenset({39, 48, 89}),
#  frozenset({39, 48, 110}),
#  frozenset({39, 48, 65}),
#  frozenset({38, 39, 170}),
#  frozenset({39, 48, 310}),
#  frozenset({39, 48, 237}),
#  frozenset({32, 38, 48}),
#  frozenset({38, 39, 48}),
#  frozenset({32, 39, 48}),
#  frozenset({38, 39, 110}),
#  frozenset({32, 39, 41}),
#  frozenset({38, 39, 48, 170}),
#  frozenset({36, 38, 39, 48}),
#  frozenset({38, 39, 41, 48}),
#  frozenset({32, 38, 39, 48}),
#  frozenset({32, 39, 41, 48}),
#  frozenset({38, 39, 48, 110})]

# %%
def gen_association_rules(matrix, itemsets, min_confidence):
    rules = []
    matrix_size = matrix.shape[0]

    for itemset in itemsets:
        itemset = list(itemset)
        antedecent_count = 1
        antedecents = set(itemset[:antedecent_count])
        consequents = set(itemset[antedecent_count:])
        while (confidence := \
            support(retail_matrix, full_set := antedecents | consequents) / \
            support(retail_matrix, antedecents)) >= min_confidence \
            and antedecent_count < len(full_set):
                
            antedecents = set(itemset[:antedecent_count])
            consequents = set(itemset[antedecent_count:])
            rules.append({
                'rule': f'{antedecents} -> {consequents}',
                'confidence': confidence,
                # TODO
                'lift': confidence / (support(retail_matrix, consequents) / matrix_size),
            })
            antedecent_count += 1
            
    return pd.DataFrame(rules)

# %%
rules = gen_association_rules(retail_matrix, retail_frequent_itemsets, 0.3)

# %%
rules.sort_values('lift', ascending=False)
# Out:
#                  rule  confidence      lift
# 30   {36} -> {38, 39}    0.662466  5.645721
# 32  {170} -> {38, 39}    0.651500  5.552270
# 9       {170} -> {38}    0.978057  5.528884
# 15       {37} -> {38}    0.973929  5.505548
# 4        {36} -> {38}    0.950272  5.371818
# 22       {41} -> {39}    0.763734  1.328723
# 6      {2238} -> {39}    0.750437  1.305591
# 5       {225} -> {39}    0.721830  1.255820
# 14       {89} -> {39}    0.716445  1.246452
# 27      {310} -> {39}    0.713955  1.242120
# 28       {36} -> {39}    0.693801  1.207056
# 21      {475} -> {39}    0.692201  1.204273
# 7        {48} -> {39}    0.691634  1.203286
# 8      {1146} -> {39}    0.689341  1.199297
# 19      {270} -> {39}    0.688581  1.197975
# 16      {271} -> {39}    0.684814  1.191421
# 0       {438} -> {39}    0.676329  1.176658
# 17      {170} -> {39}    0.664408  1.155919
# 23       {38} -> {39}    0.663311  1.154011
# 31   {36, 38} -> {39}    0.662466  1.152540
# 10       {60} -> {39}    0.660175  1.148554
# 33  {170, 38} -> {39}    0.651500  1.133463
# 2     {12925} -> {39}    0.639400  1.112411
# 29      {147} -> {39}    0.639123  1.111929
# 20      {237} -> {39}    0.636214  1.106867
# 11    {16010} -> {39}    0.629939  1.095951
# 18      {110} -> {39}    0.629563  1.095297
# 13      {101} -> {39}    0.625838  1.088816
# 26       {65} -> {39}    0.623211  1.084246
# 3       {533} -> {39}    0.620040  1.078729
# 24        {9} -> {39}    0.606414  1.055023
# 1       {185} -> {39}    0.601744  1.046898
# 12      {413} -> {39}    0.601064  1.045715
# 25       {32} -> {39}    0.557460  0.969854
